aggle/input/mars-dataset/audio/New folder (2)/Audio_Song_Actors_01-24/Actor_06/03-02-01-01-02-01-06.wav
# ...
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_14/03-02-06-02-02-02-14.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_14/03-02-05-01-02-01-14.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_14/03-02-02-02-01-02-14.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_14/03-02-06-01-02-02-14.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_14/03-02-04-01-01-01-14.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_14/03-02-03-01-01-02-14.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_14/03-02-03-02-01-01-14.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_14/03-02-05-02-01-01-14.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_14/03-02-05-02-01-02-14.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-05-01-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-05-02-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-05-01-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-03-02-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-02-02-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-06-02-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-05-01-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-06-01-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-04-01-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-02-02-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-04-02-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-06-01-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-02-01-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-02-02-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-01-01-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-06-02-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-04-01-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-01-01-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-02-01-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-04-02-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-03-01-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-06-01-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-03-02-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-05-01-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-03-02-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-05-02-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-02-01-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-06-01-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-05-02-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-06-02-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-04-01-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-01-01-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-03-01-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-02-01-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-04-01-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-03-02-02-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-06-02-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-04-02-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-02-02-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-01-01-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-05-02-01-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-04-02-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-03-01-01-02-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_03/03-02-03-01-02-01-03.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-05-01-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-06-02-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-02-01-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-05-02-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-04-02-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-03-01-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-05-01-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-03-01-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-01-01-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-01-01-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-06-01-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-06-02-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-06-02-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-03-01-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-02-02-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-03-02-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-04-01-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-06-01-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-03-01-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-05-02-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-05-01-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-02-02-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-04-02-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-05-02-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-02-02-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-04-01-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-06-01-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-05-02-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-06-01-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-02-02-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-04-02-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-04-01-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-02-01-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-04-02-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-05-01-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-02-01-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-03-02-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-01-01-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-06-02-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-03-02-02-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-04-01-01-01-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-01-01-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-03-02-01-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_13/03-02-02-01-02-02-13.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-02-01-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-06-01-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-04-02-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-06-02-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-04-01-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-02-02-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-05-02-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-03-02-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-02-02-02-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-04-01-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-03-02-02-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-04-02-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-04-02-02-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-06-01-02-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-05-01-02-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-05-01-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-05-02-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-03-01-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-03-01-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-06-02-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-05-02-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-03-02-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-01-01-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-04-02-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-05-01-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-02-01-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-06-01-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-06-02-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-01-01-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-02-01-02-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-04-01-02-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-02-02-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-04-01-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-03-01-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-01-01-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-03-02-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-06-02-02-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-05-01-02-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-03-01-02-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-02-02-01-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-06-01-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-01-01-02-01-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-02-01-01-02-07.wav
# /kaggle/input/mars-dataset/Audio_Song_Actors_01-24 (2)/Audio_Song_Actors_01-24/Actor_07/03-02-05-02-02-01-07.wav

# %%
import os
import pandas as pd

# %%
data_dir = "/kaggle/input/mars-dataset/audio/New folder (2)/Audio_Song_Actors_01-24"

# Label mappings for clarity
emotion_dict = {
    '01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad',
    '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised'
}
modality_dict = {'01': 'full-AV', '02': 'video-only', '03': 'audio-only'}
channel_dict = {'01': 'speech', '02': 'song'}
intensity_dict = {'01': 'normal', '02': 'strong'}
statement_dict = {'01': 'Kids are talking by the door', '02': 'Dogs are sitting by the door'}
gender_dict = lambda x: 'male' if int(x) % 2 else 'female'

# List to hold extracted data
data = []

# Walk through the directory and parse filenames
for actor_folder in os.listdir(data_dir):
    actor_path = os.path.join(data_dir, actor_folder)
    if not os.path.isdir(actor_path):
        continue
    for filename in os.listdir(actor_path):
        if filename.endswith('.wav'):
            parts = filename.split('.')[0].split('-')
            actor_id_str = parts[6]
            try:
                actor_id_int = int(actor_id_str)
                gender = gender_dict(actor_id_int)
            except ValueError:
                gender = 'unknown' # Or handle the error differently
                print(f"Could not parse actor_id for file: {filename}. Actor ID string: {actor_id_str}")

            data.append({
                'path': os.path.join(data_dir,actor_path, filename),
                'filename': filename,
                'modality': modality_dict[parts[0]],
                'vocal_channel': channel_dict[parts[1]],
                'emotion': emotion_dict[parts[2]],
                'intensity': intensity_dict.get(parts[3], 'normal'),
                'statement': statement_dict[parts[4]],
                'repeat': parts[5],
                'actor_id': actor_id_str,
                'gender': gender,
                'actor_folder': actor_folder
            })

# Create the DataFrame
df1 = pd.DataFrame(data)

# %%
data_dir = "/kaggle/input/mars-dataset/audio/New folder (2)/Audio_Speech_Actors_01-24"

# Label mappings for clarity
emotion_dict = {
    '01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad',
    '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised'
}
modality_dict = {'01': 'full-AV', '02': 'video-only', '03': 'audio-only'}
channel_dict = {'01': 'speech', '02': 'song'}
intensity_dict = {'01': 'normal', '02': 'strong'}
statement_dict = {'01': 'Kids are talking by the door', '02': 'Dogs are sitting by the door'}
gender_dict = lambda x: 'male' if int(x) % 2 else 'female'

# List to hold extracted data
data = []

# Walk through the directory and parse filenames
for actor_folder in os.listdir(data_dir):
    actor_path = os.path.join(data_dir, actor_folder)
    if not os.path.isdir(actor_path):
        continue
    for filename in os.listdir(actor_path):
        if filename.endswith('.wav'):
            parts = filename.split('.')[0].split('-')
            actor_id_str = parts[6]
            try:
                actor_id_int = int(actor_id_str)
                gender = gender_dict(actor_id_int)
            except ValueError:
                gender = 'unknown' # Or handle the error differently
                print(f"Could not parse actor_id for file: {filename}. Actor ID string: {actor_id_str}")

            data.append({
                'path': os.path.join(data_dir,actor_path, filename),
                'filename': filename,
                'modality': modality_dict[parts[0]],
                'vocal_channel': channel_dict[parts[1]],
                'emotion': emotion_dict[parts[2]],
                'intensity': intensity_dict.get(parts[3], 'normal'),
                'statement': statement_dict[parts[4]],
                'repeat': parts[5],
                'actor_id': actor_id_str,
                'gender': gender,
                'actor_folder': actor_folder
            })

# Create the DataFrame
df2 = pd.DataFrame(data)

# %%
df1.sample(5)
# Out:
#                                                   path  \
# 252  /kaggle/input/mars-dataset/audio/New folder (2...
# 760  /kaggle/input/mars-dataset/audio/New folder (2...
# 882  /kaggle/input/mars-dataset/audio/New folder (2...
# 298  /kaggle/input/mars-dataset/audio/New folder (2...
# 273  /kaggle/input/mars-dataset/audio/New folder (2...
#
#                      filename    modality vocal_channel emotion intensity  \
# 252  03-02-04-02-01-01-01.wav  audio-only          song     sad    strong
# 760  03-02-05-01-01-02-10.wav  audio-only          song   angry    normal
# 882  03-02-05-01-01-01-03.wav  audio-only          song   angry    normal
# 298  03-02-04-02-02-01-11.wav  audio-only          song     sad    strong
# 273  03-02-02-01-02-02-11.wav  audio-only          song    calm    normal
#
#                         statement repeat actor_id  gender actor_folder
# 252  Kids are talking by the door     01       01    male     Actor_01
# 760  Kids are talking by the door     02       10  female     Actor_10
# 882  Kids are talking by the door     01       03    male     Actor_03
# 298  Dogs are sitting by the door     01       11    male     Actor_11
# 273  Dogs are sitting by the door     02       11    male     Actor_11

# %%
df = pd.concat([df1, df2])

# Shuffle the concatenated dataframe
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.drop(['actor_id','actor_folder','filename','modality','vocal_channel','intensity','repeat'],axis=1,inplace=True)

# %%
df.sample(5)
# Out:
#                                                    path  emotion  \
# 1516  /kaggle/input/mars-dataset/audio/New folder (2...     calm
# 1929  /kaggle/input/mars-dataset/audio/New folder (2...      sad
# 1556  /kaggle/input/mars-dataset/audio/New folder (2...  neutral
# 69    /kaggle/input/mars-dataset/audio/New folder (2...  fearful
# 2073  /kaggle/input/mars-dataset/audio/New folder (2...    happy
#
#                          statement  gender
# 1516  Dogs are sitting by the door    male
# 1929  Dogs are sitting by the door    male
# 1556  Dogs are sitting by the door  female
# 69    Dogs are sitting by the door  female
# 2073  Dogs are sitting by the door  female

# %%
df.drop(['statement','gender'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                 path  emotion
# 0  /kaggle/input/mars-dataset/audio/New folder (2...     calm
# 1  /kaggle/input/mars-dataset/audio/New folder (2...     calm
# 2  /kaggle/input/mars-dataset/audio/New folder (2...  neutral
# 3  /kaggle/input/mars-dataset/audio/New folder (2...     calm
# 4  /kaggle/input/mars-dataset/audio/New folder (2...    happy

# %%
import seaborn as sns
import os
import numpy as np
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (InputLayer, TimeDistributed, Conv1D,Conv2D, MaxPooling2D,MaxPooling1D,
                                     BatchNormalization, Dropout, Flatten, LSTM, Dense)
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# 2025-06-24 06:43:58.620169: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750747438.933455      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750747439.053729      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
sns.countplot(df,x='emotion')
# Out:
# <Axes: xlabel='emotion', ylabel='count'>

# %%
df.head()
# Out:
#                                                 path  emotion
# 0  /kaggle/input/mars-dataset/audio/New folder (2...     calm
# 1  /kaggle/input/mars-dataset/audio/New folder (2...     calm
# 2  /kaggle/input/mars-dataset/audio/New folder (2...  neutral
# 3  /kaggle/input/mars-dataset/audio/New folder (2...     calm
# 4  /kaggle/input/mars-dataset/audio/New folder (2...    happy

# %% [markdown]
# ## Augmentation+MFCC

# %%
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, BatchNormalization, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# %%
SR       = 16000   # sampling rate
N_MFCC   = 40      # number of MFCCs
TEST_SZ  = 0.20    # 20% test split
RND_SEED = 42

def add_noise(data, noise_level=0.005):
    noise = np.random.randn(len(data))
    return data + noise_level * noise

def shift_pitch(data, sr, n_steps=2):
    return librosa.effects.pitch_shift(y=data, sr=sr, n_steps=n_steps)

def time_stretch(data, rate=1.1):
    return librosa.effects.time_stretch(y=data, rate=rate)


def extract_mfcc_mean(y, sr, n_mfcc=N_MFCC):
    """Compute MFCC and return mean over time → shape (n_mfcc,)"""
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    return np.mean(mfcc.T, axis=0)


def prepare_dataset(df, augment=False):
    """
    df must have columns ['path','emotion_label'].
    If augment=True, applies 1x noise, pitch, stretch PER AUDIO.
    Returns (X, y) as numpy arrays.
    """
    X, y = [], []
    for _, row in df.iterrows():
        path  = row['path']
        label = row['emotion_label']
        try:
            signal, sr = librosa.load(path, sr=SR)
        except Exception as e:
            print(f"⚠️ Could not load {path}: {e}")
            continue

        # --- original features
        feat = extract_mfcc_mean(signal, sr)
        X.append(feat); y.append(label)

        # --- augmentations (only if flag set)
        if augment:
            # noise
            x1 = add_noise(signal)
            X.append(extract_mfcc_mean(x1, sr)); y.append(label)

            # pitch up
            x2 = shift_pitch(signal, sr, n_steps=2)
            X.append(extract_mfcc_mean(x2, sr)); y.append(label)

            # time stretch
            x3 = time_stretch(signal, rate=1.1)
            X.append(extract_mfcc_mean(x3, sr)); y.append(label)

    return np.vstack(X), np.array(y)



le = LabelEncoder()
df['emotion_label'] = le.fit_transform(df['emotion'])

train_df, val_df = train_test_split(
    df, test_size=TEST_SZ, random_state=RND_SEED, stratify=df['emotion_label']
)

# prepare features
X_train, y_train = prepare_dataset(train_df, augment=True)
X_val,   y_val   = prepare_dataset(val_df,   augment=False)

# expand dims for Conv1D: (samples, timesteps=N_MFCC, channels=1)
X_train = X_train.reshape(-1, N_MFCC, 1)
X_val   = X_val.reshape(-1,   N_MFCC, 1)

# one-hot encode targets
num_classes   = len(le.classes_)
y_train_oh    = to_categorical(y_train, num_classes)
y_val_oh      = to_categorical(y_val,   num_classes)

print("Shapes:")
print(" X_train:", X_train.shape, "y_train:", y_train_oh.shape)
print("   X_val:",   X_val.shape,   "  y_val:",   y_val_oh.shape)


model = Sequential([
    Conv1D(64, kernel_size=5, activation='relu',
           input_shape=(N_MFCC,1), padding='same'),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.3),

    Conv1D(128, kernel_size=5, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.3),

    Flatten(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),

    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=Adam(1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()


history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=50,
    batch_size=32,
    callbacks=[EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)]
)

val_loss, val_acc = model.evaluate(X_val, y_val_oh, verbose=0)
print(f"\nValidation Loss: {val_loss:.4f}  —  Validation Accuracy: {val_acc:.4f}")

y_pred = np.argmax(model.predict(X_val), axis=1)
cm     = confusion_matrix(y_val, y_pred)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=le.classes_, yticklabels=le.classes_,
            cmap='Blues')
plt.title("Confusion Matrix"); plt.show()

print("\nClassification Report:")
print(classification_report(y_val, y_pred, target_names=le.classes_))
# Out:
# Shapes:
#  X_train: (7844, 40, 1) y_train: (7844, 8)
#    X_val: (491, 40, 1)   y_val: (491, 8)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1750747650.303323      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1750747650.304041      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 40, 64)              │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 40, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 20, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 20, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 20, 128)             │          41,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 20, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 10, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 10, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         327,936 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │           2,056 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 373,256 (1.42 MB)
#  Trainable params: 372,360 (1.42 MB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750747655.306970     118 service.cc:148] XLA service 0x7c9dd4004ad0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750747655.308053     118 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750747655.308072     118 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750747655.722723     118 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  56/246 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1655 - loss: 2.9031
# I0000 00:00:1750747659.680192     118 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.2112 - loss: 2.5110 - val_accuracy: 0.3666 - val_loss: 1.7778
# Epoch 2/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7140 - loss: 0.7702 - val_accuracy: 0.7169 - val_loss: 0.7628
# Epoch 34/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7225 - loss: 0.7417 - val_accuracy: 0.7210 - val_loss: 0.7675
# Epoch 35/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7407 - loss: 0.7169 - val_accuracy: 0.7210 - val_loss: 0.7764
# Epoch 36/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7507 - loss: 0.7154 - val_accuracy: 0.7434 - val_loss: 0.7401
# Epoch 37/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7363 - loss: 0.6974 - val_accuracy: 0.7658 - val_loss: 0.7054
# Epoch 38/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7513 - loss: 0.6825 - val_accuracy: 0.7413 - val_loss: 0.7116
# Epoch 39/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7552 - loss: 0.6653 - val_accuracy: 0.7413 - val_loss: 0.7067
# Epoch 40/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7629 - loss: 0.6567 - val_accuracy: 0.7576 - val_loss: 0.7223
# Epoch 41/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7469 - loss: 0.6892 - val_accuracy: 0.7454 - val_loss: 0.7134
# Epoch 42/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7678 - loss: 0.6371 - val_accuracy: 0.7515 - val_loss: 0.7269
# Epoch 43/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7611 - loss: 0.6536 - val_accuracy: 0.7312 - val_loss: 0.7543
# Epoch 44/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7578 - loss: 0.6658 - val_accuracy: 0.7556 - val_loss: 0.7247
# Epoch 45/50
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7738 - loss: 0.6394 - val_accuracy: 0.7373 - val_loss: 0.7226
#
# Validation Loss: 0.7054  —  Validation Accuracy: 0.7658
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.87      0.91      0.89        75
#         calm       0.79      0.85      0.82        75
#      disgust       0.71      0.56      0.63        39
#      fearful       0.73      0.71      0.72        75
#        happy       0.80      0.73      0.76        75
#      neutral       0.85      0.87      0.86        38
#          sad       0.72      0.65      0.69        75
#    surprised       0.62      0.82      0.70        39
#
#     accuracy                           0.77       491
#    macro avg       0.76      0.76      0.76       491
# weighted avg       0.77      0.77      0.76       491

# %% [markdown]
# ## MFCC+dMFCC+ddMFCC+Augmentation

# %%
SR = 16000                # Sampling rate
TARGET_DURATION = 5       # in seconds
MAX_LEN = SR * TARGET_DURATION  # 80000 samples

def pad_or_crop(signal, sr=SR, target_duration=TARGET_DURATION):
    max_len = sr * target_duration
    if len(signal) < max_len:
        return np.pad(signal, (0, max_len - len(signal)))
    else:
        return signal[:max_len]

# %%
def extract_mfcc_full(y, sr, n_mfcc=40):
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    mfcc_delta = librosa.feature.delta(mfcc)
    mfcc_delta2 = librosa.feature.delta(mfcc, order=2)
    return np.stack([mfcc.T, mfcc_delta.T, mfcc_delta2.T], axis=-1)  # (T, n_mfcc, 3)

# %%
def prepare_dataset(df, sr=SR, n_mfcc=40, augment=False):
    X, y = [], []
    for _, row in df.iterrows():
        path = row['path']
        label = row['emotion_label']
        try:
            signal, sr = librosa.load(path, sr=sr)
            signal = pad_or_crop(signal, sr)

            # Original
            X.append(extract_mfcc_full(signal, sr, n_mfcc))
            y.append(label)

            if augment:
                # 1. Add noise
                noisy = add_noise(signal)
                X.append(extract_mfcc_full(pad_or_crop(noisy, sr), sr, n_mfcc))
                y.append(label)

                # 2. Pitch up
                pitch_up = shift_pitch(signal, sr, n_steps=2)
                X.append(extract_mfcc_full(pad_or_crop(pitch_up, sr), sr, n_mfcc))
                y.append(label)

                # 3. Pitch down
                pitch_down = shift_pitch(signal, sr, n_steps=-2)
                X.append(extract_mfcc_full(pad_or_crop(pitch_down, sr), sr, n_mfcc))
                y.append(label)

                # 4. Time stretch (faster)
                stretch_fast = time_stretch(signal, rate=1.2)
                X.append(extract_mfcc_full(pad_or_crop(stretch_fast, sr), sr, n_mfcc))
                y.append(label)

                # 5. Time stretch (slower)
                stretch_slow = time_stretch(signal, rate=0.8)
                X.append(extract_mfcc_full(pad_or_crop(stretch_slow, sr), sr, n_mfcc))
                y.append(label)

        except Exception as e:
            print(f"⚠️ Error loading {path}: {e}")
            continue

    return np.array(X), np.array(y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Label encode
le = LabelEncoder()
df['emotion_label'] = le.fit_transform(df['emotion'])

# Split
train_df, val_df = train_test_split(
    df, test_size=0.2, random_state=42, stratify=df['emotion_label']
)

# Prepare features
X_train, y_train = prepare_dataset(train_df, augment=True)
X_val,   y_val   = prepare_dataset(val_df, augment=False)

# One-hot encode labels
num_classes = len(le.classes_)
y_train_oh = to_categorical(y_train, num_classes)
y_val_oh   = to_categorical(y_val, num_classes)

print("X_train:", X_train.shape, "y_train:", y_train_oh.shape)
print("X_val:  ", X_val.shape,   "y_val:  ", y_val_oh.shape)
# Out:
# X_train: (11766, 157, 40, 3) y_train: (11766, 8)
# X_val:   (491, 157, 40, 3) y_val:   (491, 8)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization, SpatialDropout2D
from tensorflow.keras.optimizers import Adam

input_shape = X_train.shape[1:]  # (T, n_mfcc, 3)

model = Sequential([
    Conv2D(32, (3,3), activation='relu', padding='same', input_shape=input_shape),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    SpatialDropout2D(0.2),

    Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    SpatialDropout2D(0.2),

    Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    SpatialDropout2D(0.2),

    Flatten(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),  # ✅ regular dropout here

    Dense(num_classes, activation='softmax')
])

model.compile(optimizer=Adam(1e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 157, 40, 32)         │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 157, 40, 32)         │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 78, 20, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout2d (SpatialDropout2D) │ (None, 78, 20, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 78, 20, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 78, 20, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 39, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout2d_1                  │ (None, 39, 10, 64)          │               0 │
# │ (SpatialDropout2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 39, 10, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 39, 10, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 19, 5, 128)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout2d_2                  │ (None, 19, 5, 128)          │               0 │
# │ (SpatialDropout2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 12160)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │       3,113,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 8)                   │           2,056 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,210,440 (12.25 MB)
#  Trainable params: 3,209,480 (12.24 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
]

# %%
from tensorflow.keras.callbacks import EarlyStopping

history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=50,
    batch_size=32,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 19s 26ms/step - accuracy: 0.2883 - loss: 2.1366 - val_accuracy: 0.5275 - val_loss: 1.3620 - learning_rate: 0.0010
# Epoch 2/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4868 - loss: 1.3948 - val_accuracy: 0.6701 - val_loss: 0.9319 - learning_rate: 0.0010
# Epoch 3/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6259 - loss: 1.0290 - val_accuracy: 0.6843 - val_loss: 0.8630 - learning_rate: 0.0010
# Epoch 4/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6846 - loss: 0.8648 - val_accuracy: 0.7800 - val_loss: 0.6455 - learning_rate: 0.0010
# Epoch 5/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7156 - loss: 0.8003 - val_accuracy: 0.7352 - val_loss: 0.7253 - learning_rate: 0.0010
# Epoch 6/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7595 - loss: 0.6669 - val_accuracy: 0.7882 - val_loss: 0.5951 - learning_rate: 0.0010
# Epoch 7/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8157 - loss: 0.5207 - val_accuracy: 0.7699 - val_loss: 0.6576 - learning_rate: 0.0010
# Epoch 8/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8403 - loss: 0.4471 - val_accuracy: 0.8004 - val_loss: 0.5924 - learning_rate: 0.0010
# Epoch 9/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8584 - loss: 0.4031 - val_accuracy: 0.8065 - val_loss: 0.6909 - learning_rate: 0.0010
# Epoch 10/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8856 - loss: 0.3294 - val_accuracy: 0.8004 - val_loss: 0.6150 - learning_rate: 0.0010
# Epoch 11/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9023 - loss: 0.2853 - val_accuracy: 0.8126 - val_loss: 0.5638 - learning_rate: 0.0010
# Epoch 12/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9076 - loss: 0.2644 - val_accuracy: 0.7943 - val_loss: 0.6249 - learning_rate: 0.0010
# Epoch 13/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9175 - loss: 0.2385 - val_accuracy: 0.7556 - val_loss: 0.8194 - learning_rate: 0.0010
# Epoch 14/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9146 - loss: 0.2418
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9146 - loss: 0.2418 - val_accuracy: 0.8004 - val_loss: 0.6372 - learning_rate: 0.0010
# Epoch 15/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9310 - loss: 0.1858 - val_accuracy: 0.8167 - val_loss: 0.5776 - learning_rate: 5.0000e-04
# Epoch 16/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9549 - loss: 0.1383 - val_accuracy: 0.8086 - val_loss: 0.6241 - learning_rate: 5.0000e-04
# Epoch 17/50
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9627 - loss: 0.1136
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9627 - loss: 0.1137 - val_accuracy: 0.8208 - val_loss: 0.5873 - learning_rate: 5.0000e-04
# Epoch 18/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9624 - loss: 0.1065 - val_accuracy: 0.8289 - val_loss: 0.5842 - learning_rate: 2.5000e-04
# Epoch 19/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9735 - loss: 0.0817 - val_accuracy: 0.8126 - val_loss: 0.5785 - learning_rate: 2.5000e-04
# Epoch 20/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9753 - loss: 0.0766
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9753 - loss: 0.0766 - val_accuracy: 0.8330 - val_loss: 0.6144 - learning_rate: 2.5000e-04
# Epoch 21/50
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9766 - loss: 0.0699 - val_accuracy: 0.8086 - val_loss: 0.6406 - learning_rate: 1.2500e-04

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Predict
y_pred = np.argmax(model.predict(X_val), axis=1)

# Confusion matrix
cm = confusion_matrix(y_val, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix"); plt.show()

# Classification report
print(classification_report(y_val, y_pred, target_names=le.classes_))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
#               precision    recall  f1-score   support
#
#        angry       0.87      0.91      0.89        75
#         calm       0.90      0.81      0.85        75
#      disgust       0.94      0.77      0.85        39
#      fearful       0.73      0.81      0.77        75
#        happy       0.79      0.79      0.79        75
#      neutral       0.80      0.87      0.84        38
#          sad       0.78      0.71      0.74        75
#    surprised       0.74      0.87      0.80        39
#
#     accuracy                           0.81       491
#    macro avg       0.82      0.82      0.82       491
# weighted avg       0.82      0.81      0.81       491

# %%
model.save("/kaggle/working/emotion_recognition_model(new).h5")
